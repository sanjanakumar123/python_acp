# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjanakumar123/python_acp/blob/main/number_guess.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# computer selects random number
secret_number = random.randint(1, 50)

# total attempts
attempts = 5

print("🎮 Welcome to the Number Guessing Game!")
print("Guess the number between 1 and 50")
print("You have 5 attempts.\n")

# while loop for attempts
while attempts > 0:

    # user input
    guess = int(input("Enter your guess: "))

    # correct guess
    if guess == secret_number:
        print("🎉 Correct! You won!")
        break

    # calculate difference
    difference = abs(secret_number - guess)

    # hint system
    if difference >= 20:
        print("🧊 Ice Cold")

    elif difference >= 10:
        print("🥶 Cold")

    elif difference >= 5:
        print("🌡️ Warm")

    else:
        print("🔥 Hot")

    # decrease attempts
    attempts -= 1

    # show remaining hearts
    print("Remaining Lives: ", end="")

    for i in range(attempts):
        print("❤️", end=" ")

    print("\n")

# loss condition
if attempts == 0:
    print("❌ Game Over!")
    print("The secret number was:", secret_number)
